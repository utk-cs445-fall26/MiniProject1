# %% [markdown]
# # Description
#
# ### Goals
#
# My goal is to compare the first two Harry Potter books and The Fellowship of the Ring. I want to compare the most common words and how they differ in uses between the books.
#
# ### Ways to Achieve Them
#
# I will get all of the .txt versions of the books online. I will then run code to look for the most frecently used words in each then compare the most used words to each other. I will then run another code to specific look for the most used words of each book and compare them to how frequent they came up in the other book. Finally I will make graphs and tables showing my results.
