# %%
My goals with this project is to determine whether one author prefers certain words more than a different author, or whether there are words that
authors use universally (other than the obvious ones). To do this, I will first compare the frequencys at which words appear, then try to narrow down
which words are truly unique to the author. To gather the data for this analysis, I will pull full-text works from the Project Gutenberg online library (Books are TBD)
selecting multiple texts per author. I will then compare word frequencies both within a single author's body of work and across different authors to distinguish
idiosyncratic word choices from universally common ones.
