# %% [markdown]
# # MiniProject 1
#
# In late March 2026, a prod sourcemap was exposed for Anthropic's Claude Code project, allowing reconstruction of the source code source files. Our group will split this up and handle with care as this real production code.
#
# As this is a large project, our group will dicuss how to attack it and ultimately try to tear down what went wrong alongside what to learn from both the CI failure and the actual code itself.
