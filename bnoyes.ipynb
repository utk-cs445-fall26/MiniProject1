# %%
# Mini Project Idea

## Goal
My goal is to analyze airplane flight delays in the United States and investigate what factors are associated with longer or more frequent delays.

## Data Source
I plan to use historical flight data from the U.S. Department of Transportation's Bureau of Transportation Statistics.

## Comparisons
I plan to compare flight delays based on factors such as airline, airport, time of day, and day or month of travel
