# %% [markdown]
# # Mini Project 1
#
# ## Research Question
#
# How has the activity of a website changed over time?
#
# ## Data Source
#
# I plan to use data from ___. Still thinking
#
# ## Approach
#
# I will collect historical snapshot data for several websites and compare
# their activity over time. I will look at the number of snapshots and how
# frequently each website was archived.
#
# ## Goal
#
# The goal is to determine whether the archival activity shows meaningful
# differences in how the websites have changed over time.
