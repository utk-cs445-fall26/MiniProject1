# %% [markdown]
# ### Goals
#
# - One of the goals I hope to complete in this assignment is to pick two books by
#   the same author and compare what the most-used words are between the two. The two books I will be comparing are *Macbeth* and *Romeo and    Juliet* by William Shakespeare.
# - Another goal is to compare the top words used from two books with two different authors.
#   This will show that there is a distinction in writing styles. I will do either *Macbeth* or *Romeo and Juliet* compared with *The Duchess* by John Webster, because they were in the same era.
# - I might also pull a set of books and compare them with each other, seeing what words appear more frequently with others.
# - With all this data, I can get an idea of how word-frequency patterns can shape an author's writing style,
#   with the help of Python.
#
# - [Romeo and Juliet](https://www.gutenberg.org/ebooks/1112)
# - [Macbeth](https://www.gutenberg.org/ebooks/1533)
# - [The Duchess of Malfi](https://www.gutenberg.org/ebooks/2232)
