# %% [markdown]
# My goal is to compare word frequencies between the following cookbooks:
#
# "Cookery and Dining in Imperial Rome" by Apicius (2009): https://www.gutenberg.org/cache/epub/29728/pg29728-images.html
#
# "A guide to modern cookery" by A. Escoffier: https://www.gutenberg.org/cache/epub/71395/pg71395-images.html
#
# "Apicii librorum X qui dicuntur De re coquinaria quae extant" by Apicius: https://www.gutenberg.org/cache/epub/16439/pg16439-images.html
#
# In order to find out:
# 1. How language in a "modern" cookbook differs from a historical one
# 2. How Apicius's two books differ in variety of words in each language
# 3. How ingredients differ between both cookbooks written in English
#
# The site https://www.gutenberg.org/ has a selection of cookbooks, including many historical cookbooks that feature ancient recipes in modern day english. I would like to parse through each of the three books mentioned, in order to better understand the ingredients used in each, the word use in each, and how word choice is affected by the context of each book.
#
# To do this, I plan to...
# 1. Gather the word counts from each book
# 2. Refine the data from each (exclude irrelevant words, etc)
# 3. Plot any relevant word data side by side
#
# My data will be presented in graphs and bullet points, based in how each conclusion is best represented. I may include snippets of text as examples.
#
# Sarah Gaddis (spastor)
