# %% [markdown]
# My goal is to use what I learn in this class to make parsing data sets faster for CTFs and log anaylsis. I plan on doing this by using the tools learned throughout this class and finding tools that can help to automate the process while being able to draw conclusions based on the provided data and its source.
