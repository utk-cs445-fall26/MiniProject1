# %% [markdown]
# Project Goal:
# Use Digital Archaeology skills to analyze texts for certain patterns and trends.
#
# Idea:
# Find two authors who have made books in the same two genres and compare word frequency, average sentence length, and unique word count.
