# %% [markdown]
# # Goals
#
# I want to learn how to use BeautifulSoup to parse html and find the words in an html book on http://www.fullbooks.com/
#
# I also need to figure out how to filter the words and make comparisons between the books/authors.
#
# ## Steps to achieve goal
#
# I probably need to work with the requests library first to see the bare html retrieved.
# I then need to work with BeautifulSoup to try to parse the words without html code in it
# Then I can do aggregate counts for words and then move on to comparisons
