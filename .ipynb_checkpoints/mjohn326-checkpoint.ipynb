# %% [markdown]
# For my first objective, I plan on comparing the word frequencies in "The Odyssey" with "The Iliad", both written by Homer.
#
# For my second objective, I will compare the word frequencies in "Undine" by Freiherr de Friedrich Heinrich Karl La Motte-Fouqué with
# "The Romance of Tristan and Iseult" by Joseph Bédier.
#
# To compare word frequencies, I would grab the two text I will use to compare. Then, create dictionaires for both, so when I
# split the words, I can populate them where each word would be in its own index. After sorting the dictionaries, I will plot the results.
