# %%
Goals= """

DATA: 

Rollo in Scotland by Jacob Abbott:    'https://www.gutenberg.org/ebooks/25174.txt.utf-8',
Rollo in Switzerland by Jacob Abbott: 'https://www.gutenberg.org/ebooks/22377.txt.utf-8',
The Young Adventurer; or, Tom's Trip Across the Plains by Jr. Horatio Alger:     'https://www.gutenberg.org/ebooks/27300.txt.utf-8',

GOAL:

First compare the two Jacob Abbott books for their word frequencies, and then compare one of the Jacob Abbott books with the Jr. Horatio Alger's book.
This will help us understand how the word choices are for adventure textbooks and how they change with authors and the story.

WAYS TO ACHIEVE THE GOAL:

- To make it even and uniform, I first need to remove the license and other unwanted pages in the book.
- Then, instead of raw word frequency calculation, I need to come up with a logic to get the average representation
as it would be unfair if a book has a lot of words in general and the other has less.
- First, I would analyze the two books by Jacob Abbott to see the differences in their word frequencies, and then
compare on of them with the other book by Jr. Horatio Alger.

"""
