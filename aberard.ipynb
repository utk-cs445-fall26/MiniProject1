# %% [markdown]
# # Goals
#
# The goal of this assignment is to look at two written works of a single author and compare word frequency as well as compare word freqauencies between two different authors. We will use The Illiad and the Odyssey as our two works from a single author and we will use Pride and Prejudice and the Illiad for the two different authors.

# %% [markdown]
# # How to Achieve Goals
#
# Remove licensing and other unwanted pages like the table of contents to "clean" the data. This would also include removing numbers and punctuation. I would then find the most used words in each work and scale proportionally to how long the book is to make a fair comparison between the two.
